# %%
import pandas as pd
import pathlib
from cfdmod.analysis.inflow.profile import InflowProfile

data_folder = pathlib.Path("./fixtures/tests/inflow/pitot_inlet")
profile = InflowProfile.from_folder(data_folder)
turbulent_intersity_data = profile.calculate_turbulence_intensity(for_components=["ux", "uy"])
turbulent_intersity_data
# Out:
#      point_idx      I_ux      I_uy
# 0            0  0.113024  0.300871
# 1            1  0.092929  0.298180
# 2            2  0.076789  0.296404
# 3            3  0.063602  0.295198
# 4            4  0.052701  0.294360
# ..         ...       ...       ...
# 248        248  0.003615 -0.269487
# 249        249  0.003638 -0.229840
# 250        250  0.003660 -0.201775
# 251        251  0.003683 -0.180914
# 252        252  0.003706 -0.164835
#
# [253 rows x 3 columns]
