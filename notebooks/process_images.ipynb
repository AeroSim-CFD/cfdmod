# %%
import PIL
from PIL import Image
import pathlib

def paste_watermark(main_image: Image, watermark_image: Image):
    """Adds a watermark to the main image

    Args:
        main_image (Image): Main Image
        watermark_image (Image): Watermark image
    """
    OFFSET = 40
    # position = (main_image.size[0] - watermark_image.size[0] - OFFSET, main_image.size[1] - watermark_image.size[1] - OFFSET)
    position = (OFFSET, OFFSET)
    main_image.paste(
        watermark_image,
        position,
        watermark_image,
    )

images_path = pathlib.Path("/home/ubuntu/Documentos/Repositories/insightv/insight/volume/045")
watermark_path = pathlib.Path("/home/ubuntu/Documentos/Repositories/insightv/insight/static/img/dark_logo.png")

watermark_img = Image.open(watermark_path)
w_size = [int(s * 0.7) for s in watermark_img.size]
print(w_size)
watermark_img = watermark_img.resize(w_size)

image_prefix = "045"

files_list = [f for f in images_path.iterdir() if f.is_file()]
files_list = [f for f in files_list if f.name.startswith(image_prefix)]

for file in files_list:
    t_img = Image.open(file)
    paste_watermark(t_img, watermark_img)
    t_img.save(file.parent / ("watermarked_" + file.name))
    print(file, file.parent / ("watermarked_" + file.name))
# Out:
# [184, 42]
# /home/ubuntu/Documentos/Repositories/insightv/insight/volume/045/045.0021.png /home/ubuntu/Documentos/Repositories/insightv/insight/volume/045/watermarked_045.0021.png
# /home/ubuntu/Documentos/Repositories/insightv/insight/volume/045/045.0147.png /home/ubuntu/Documentos/Repositories/insightv/insight/volume/045/watermarked_045.0147.png
# /home/ubuntu/Documentos/Repositories/insightv/insight/volume/045/045.0086.png /home/ubuntu/Documentos/Repositories/insightv/insight/volume/045/watermarked_045.0086.png
# /home/ubuntu/Documentos/Repositories/insightv/insight/volume/045/045.0068.png /home/ubuntu/Documentos/Repositories/insightv/insight/volume/045/watermarked_045.0068.png
# /home/ubuntu/Documentos/Repositories/insightv/insight/volume/045/045.0040.png /home/ubuntu/Documentos/Repositories/insightv/insight/volume/045/watermarked_045.0040.png
# ...

# %%
import pathlib
from PIL import Image

images_path = pathlib.Path("/home/ubuntu/Desktop/animation_frames")

for i in [i for i in range(780)]:
    try:
        with Image.open(images_path / f"animation.{i:04d}.png") as img:
            # Calculate the new dimensions
            new_dimensions = (int(img.width * 0.5), int(img.height * 0.5))
            # Resize the image
            resized_img = img.resize(new_dimensions, Image.LANCZOS)
            offset = int((img.width - img.height) / 2)
            cropped_img = img.crop((offset, 0, img.width - offset, img.height))
            
            # Save the resized image
            resized_img.save(images_path / f"animation.{i+390:04d}.png")
            cropped_img.save(images_path / f"cropped.animation.{i:04d}.png")
            (images_path / f"animation.{i:04d}.resized.png").unlink()
    except:
        print(i)
        continue
# Out:
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# 784
# ...

# %%
import pathlib
import shutil

images_path = pathlib.Path("/home/ubuntu/Desktop/plane_animation_LP/opacity")

for i in range(390):
    file_name = images_path / f"animation.{i:04d}.png"
    new_file_name = images_path / f"animation.{i+390:04d}.png"
    
    shutil.copy(file_name, new_file_name)
